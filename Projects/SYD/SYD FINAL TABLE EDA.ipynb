# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Load your dataset
# Replace 'your_dataset.csv' with your file name or URL
data = pd.read_csv('SYD_Final_Master_Table.csv')

# %%
# Display basic info about the dataset
print("Data Overview:")
print(data.head())  # Display the first few rows
print(data.info())   # Summary info about columns, data types, and null values
# Out:
# Data Overview:
#                          appointment_ID                            patient_id  \
# 0  2dda1d44-9b23-4b5b-b26d-b7be68df4480  f5dfeb9a-e37a-4511-ac8f-7a9c73bf50ed
# 1  1baf9d5f-2b36-4428-aa64-eded97001a56  1cdb93d5-b2b1-4240-93c7-43cf70ef26e9
# 2  c2083578-d143-4029-8d67-41b106a6ac11  03d4b627-b175-4755-b439-65d98c812065
# 3  fabc0dff-97af-42fd-949d-e1e771874884  24dbff72-8762-4f1e-b614-d4387c723c94
# 4  933bf6db-a40c-4dea-bfb4-7af2cdc8f65d  bfecb6ad-0ec5-4c4c-ad2c-04db5030d626
#
#     Feedback count  patient_active  q4_rating q4_rating_classification  \
# 0  Single feedback            True          5                     High
# 1  Single feedback            True          5                     High
# 2  Single feedback            True          5                     High
# 3  Single feedback            True          5                     High
# 4  Single feedback            True          5                     High
#
#    q5_rating q5_rating_classification  q6_rating q6_rating_classification  \
# 0          5                     High          4                     High
# 1          5                     High          5                     High
# 2          5                     High          5                     High
# 3          5                     High          4                     High
# 4          5                     High          5                     High
#
#    ...  practitioner_years_final practitioner_active     Yr-Qtr  \
# 0  ...               16-20 years                TRUE  2020 Qtr2
# 1  ...                5-10 years                TRUE  2020 Qtr2
# 2  ...         Less than 5 years                TRUE  2020 Qtr2
# 3  ...                   Unknown                TRUE  2020 Qtr2
# 4  ...                5-10 years                TRUE  2020 Qtr2
#
#   appointment_date  consultation_fee mins_appointment_duration  \
# 0        6/20/2020           Unknown                        60
# 1        6/18/2020           Unknown                        30
# 2        5/15/2020           Unknown                        30
# 3        5/16/2020               500                        30
# 4        5/27/2020           Unknown                        15
#
#     Duration_final  payment_method  \
# 0  46 mins to 1 hr  online_credits
# 1       15-30 mins  online_credits
# 2       15-30 mins            free
# 3       15-30 mins  online_credits
# 4       15-30 mins            free
#
#                                               reason is_online
# 0                   35 weeks and 2 days consultation      True
# 1                     Aschemic heart disease; HASCVD      True
# 2                                               ayan      True
# 3  Beside the lower part of my ear, there is a du...      True
# 4                                     blood in stool      True
#
# [5 rows x 32 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2551 entries, 0 to 2550
# Data columns (total 32 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   appointment_ID             2551 non-null   object
#  1   patient_id                 2551 non-null   object
#  2   Feedback count             2551 non-null   object
#  3   patient_active             2551 non-null   bool
#  4   q4_rating                  2551 non-null   int64
#  5   q4_rating_classification   2551 non-null   object
#  6   q5_rating                  2551 non-null   int64
#  7   q5_rating_classification   2551 non-null   object
#  8   q6_rating                  2551 non-null   int64
#  9   q6_rating_classification   2551 non-null   object
#  10  q7_rating                  2551 non-null   int64
#  11  q7_rating_classification   2551 non-null   object
#  12  q8_rating                  2551 non-null   int64
#  13  q8_rating_classification   2551 non-null   object
#  14  is_complaint               2551 non-null   bool
#  15  ratings_comment            2549 non-null   object
#  16  ratings_comment_final      2551 non-null   object
#  17  practitioner_id            2551 non-null   object
#  18  practitioner_name          2551 non-null   object
#  19  specialisation_name        2551 non-null   object
#  20  specialty_type             2551 non-null   object
#  21  practitioner_years         2551 non-null   object
#  22  practitioner_years_final   2551 non-null   object
#  23  practitioner_active        2551 non-null   object
#  24  Yr-Qtr                     2551 non-null   object
#  25  appointment_date           2551 non-null   object
#  26  consultation_fee           2551 non-null   object
#  27  mins_appointment_duration  2551 non-null   int64
#  28  Duration_final             2551 non-null   object
#  29  payment_method             2551 non-null   object
#  30  reason                     2551 non-null   object
#  31  is_online                  2551 non-null   bool
# dtypes: bool(3), int64(6), object(23)
# memory usage: 585.6+ KB
# None

# %%
# Descriptive statistics
print("Descriptive Statistics:")
print(data.describe())
print("-------")
median_by_specialty = data.groupby(['specialty_type', 'q8_rating_classification'])['mins_appointment_duration'].median()
print(median_by_specialty)
# Out:
# Descriptive Statistics:
#          q4_rating    q5_rating    q6_rating    q7_rating    q8_rating  \
# count  2551.000000  2551.000000  2551.000000  2551.000000  2551.000000
# mean      3.696982     3.619757     3.490396     3.430811     3.620149
# std       1.806173     1.820059     1.819234     1.857633     1.834840
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       1.000000     1.000000     1.000000     1.000000     1.000000
# 50%       5.000000     5.000000     5.000000     5.000000     5.000000
# 75%       5.000000     5.000000     5.000000     5.000000     5.000000
# max       5.000000     5.000000     5.000000     5.000000     5.000000
#
#        mins_appointment_duration
# count                2551.000000
# mean                   28.524892
# std                   116.710794
# min                 -1423.000000
# 25%                    27.000000
# 50%                    30.000000
# 75%                    30.000000
# max                  2892.000000
# -------
# specialty_type            q8_rating_classification
# Invalid                   High                        25.0
# Non-medical areas         High                        30.0
#                           Low                         30.0
# Non-surgical specialties  High                        30.0
#                           Low                         30.0
# Supporting specialties    Low                         30.0
# Surgical specialties      High                        30.0
#                           Low                         30.0
# Name: mins_appointment_duration, dtype: float64

# %%
# Check for missing values
print("Missing Values:")
print(data.isnull().sum())
# Out:
# Missing Values:
# appointment_ID               0
# patient_id                   0
# Feedback count               0
# patient_active               0
# q4_rating                    0
# q4_rating_classification     0
# q5_rating                    0
# q5_rating_classification     0
# q6_rating                    0
# q6_rating_classification     0
# q7_rating                    0
# q7_rating_classification     0
# q8_rating                    0
# q8_rating_classification     0
# is_complaint                 0
# ratings_comment              2
# ratings_comment_final        0
# practitioner_id              0
# practitioner_name            0
# specialisation_name          0
# specialty_type               0
# practitioner_years           0
# practitioner_years_final     0
# practitioner_active          0
# Yr-Qtr                       0
# appointment_date             0
# consultation_fee             0
# mins_appointment_duration    0
# Duration_final               0
# payment_method               0
# reason                       0
# is_online                    0
# dtype: int64

# %%
# Numerical Columns Values
print("q4 values: " + str(data['q4_rating'].unique()))
print("q5 values: " + str(data['q5_rating'].unique()))
print("q6 values: " + str(data['q6_rating'].unique()))
print("q7 values: " + str(data['q7_rating'].unique()))
print("q8: " + str(data['q8_rating'].unique()))
print("practitioner_years values: " + str(data['practitioner_years'].unique()))
print("consultation_fee values: " + str(data['consultation_fee'].unique()))
print("mins_appointment_duration: " + str(data['mins_appointment_duration'].unique()))
# Out:
# q4 values: [5 1 4 3 2]
# q5 values: [5 1 4 3 2]
# q6 values: [4 5 1 3 2]
# q7 values: [3 4 5 1 2]
# q8: [5 1 4 3 2]
# practitioner_years values: ['20' '5' '2' 'Unknown' '9' '30' '1' '13' '22' '15' '38' '23' '19' '14'
#  '16' '10' '3' '25' '18' '4' '11' '7' '6' '12' '17' '21' '8']
# consultation_fee values: ['Unknown' '500' '600' '700' '200' '650' '800' '300' '400' '150' '1000'
#  '550' '950']
# mins_appointment_duration: [   60    30    15 -1405   180    34     8    21    37    19    27   540
#     13   120    43    18    51    10     9    23    28    20    40    17
#      7    14    29    35    22    47    55    33    25  -313    36    70
#     66    38    95  -169    41    42    32    12    50    44 -1423    52
#     24    11    86    58    73    26 -1357 -1378    16 -1396    56    -3
#      1     6    91 -1402 -1412     0 -1386    46    85   -85   141   -73
#     -8   -53    81    53   -23   105    -6     5    59    65   109    48
#     31   -30    93    79   -10    49    62    -2   115    80   103   106
#    240    64    69   111   -65   167   -32   136   113    74    96    97
#      3   -11   -76    71   -45   -87   208     4    90   558    54    39
#      2  -218    67   -94    61   156   -33   108 -1120    -4   112  -146
#     45    84    88   425   101   117   131   -77   331   -56   163   116
#   1192   122   121 -1410    72   124  -267    68  2892    99   150   -70
#    -43  -111   600   -14    57  -329   100   110   -25    82    87    77
#    -17   -35   -31   286   290    75   129   291    -1   480   205   341
#    382]

# %%
# Create a box plot
plt.boxplot(data['mins_appointment_duration'])
plt.title('Box Plot of Appointment Durations')
plt.ylabel('Duration (mins)')

# Calculate quartiles
quartiles = np.percentile(data['mins_appointment_duration'], [25, 50, 75])
lower_quartile, median, upper_quartile = quartiles
iqr = upper_quartile - lower_quartile

# Calculate outliers
lower_bound = 5
upper_bound = 180
# Convert all negative values to positive values
data.loc[data['mins_appointment_duration'] < 0, 'mins_appointment_duration'] *= -1
# 5 minutes is the minimum appointment time
outliers = [val for val in data['mins_appointment_duration'] if val < lower_bound or val > upper_bound]


print(f"Lower Quartile: {lower_quartile}")
print(f"Median: {median}")
print(f"Upper Quartile: {upper_quartile}")
print(f"IQR: {iqr}")
print(f"Lower Bound: {lower_bound}")
print(f"Upper Bound: {upper_bound}")
print(f"Number of Outliers: {len(outliers)}")
print(f"Outliers: {outliers}")

plt.show()
# Out:
# Lower Quartile: 27.0
# Median: 30.0
# Upper Quartile: 30.0
# IQR: 3.0
# Lower Bound: 5
# Upper Bound: 180
# Number of Outliers: 62
# Outliers: [1405, 540, 313, 1423, 1357, 1378, 1396, 1396, 3, 1, 1402, 1412, 0, 1386, 2, 240, 3, 208, 4, 558, 1, 0, 2, 3, 218, 1, 2, 1120, 4, 2, 2, 425, 0, 331, 331, 2, 1192, 1410, 3, 4, 0, 0, 267, 3, 2892, 2, 2, 600, 329, 286, 2, 4, 4, 290, 291, 1, 480, 205, 341, 382, 2, 0]

# %%
# Exclude outliers from the DataFrame
data = data[~data['mins_appointment_duration'].isin(outliers)]

# %%
# Categorical Columns Values
print("Patient Active values: " + str(data['patient_active'].unique()))
print("Is complaint values: " + str(data['is_complaint'].unique()))
print("Is complaint values: " + str(data['is_complaint'].unique()))
# 62 specializations
print("specialisation_name:", len(data['specialisation_name'].unique()))
# Out:
# Patient Active values: [ True False]
# Is complaint values: [False  True]
# Is complaint values: [False  True]
# specialisation_name: 62

# %%
data
# Out:
#                             appointment_ID  \
# 0     2dda1d44-9b23-4b5b-b26d-b7be68df4480
# 1     1baf9d5f-2b36-4428-aa64-eded97001a56
# 2     c2083578-d143-4029-8d67-41b106a6ac11
# 3     fabc0dff-97af-42fd-949d-e1e771874884
# 4     933bf6db-a40c-4dea-bfb4-7af2cdc8f65d
# ...                                    ...
# 2544  826bc0e9-eaeb-4152-92c1-b193b2ec497a
# 2546  f01245f3-ad92-4e8d-8267-b6d5e0b52d47
# 2547  39e14fc6-7802-46e1-81e4-6c69311be68a
# 2548  d12af0dd-c1ae-4f0d-90c7-2703bfdc1445
# 2549  61fba972-d8c6-4b69-b5ba-3f075c83e826
#
#                                 patient_id   Feedback count  patient_active  \
# 0     f5dfeb9a-e37a-4511-ac8f-7a9c73bf50ed  Single feedback            True
# 1     1cdb93d5-b2b1-4240-93c7-43cf70ef26e9  Single feedback            True
# 2     03d4b627-b175-4755-b439-65d98c812065  Single feedback            True
# 3     24dbff72-8762-4f1e-b614-d4387c723c94  Single feedback            True
# 4     bfecb6ad-0ec5-4c4c-ad2c-04db5030d626  Single feedback            True
# ...                                    ...              ...             ...
# 2544  138bcb5e-8187-4efc-976c-36feb35530ce  Single feedback            True
# 2546  cff13aa0-61ab-4e51-abd6-34623ca8bf21  Single feedback            True
# 2547  06a53a31-9287-4e54-80b0-910e6d1ec8e9  Single feedback            True
# 2548  d6fbc424-989b-447b-a766-4dbfb81cb32b  Single feedback            True
# 2549  c6a25a63-e54d-4638-86cc-38c216d9c3d4  Single feedback            True
#
#       q4_rating q4_rating_classification  q5_rating q5_rating_classification  \
# 0             5                     High          5                     High
# 1             5                     High          5                     High
# 2             5                     High          5                     High
# 3             5                     High          5                     High
# 4             5                     High          5                     High
# ...         ...                      ...        ...                      ...
# 2544          1                      Low          1                      Low
# 2546          5                     High          5                     High
# 2547          5                     High          5                     High
# 2548          5                     High          5                     High
# 2549          5                     High          5                     High
#
#       q6_rating q6_rating_classification  ...  practitioner_years_final  \
# 0             4                     High  ...               16-20 years
# 1             5                     High  ...                5-10 years
# 2             5                     High  ...         Less than 5 years
# 3             4                     High  ...                   Unknown
# 4             5                     High  ...                5-10 years
# ...         ...                      ...  ...                       ...
# 2544          1                      Low  ...                5-10 years
# 2546          5                     High  ...               16-20 years
# 2547          5                     High  ...        More than 20 years
# 2548          4                     High  ...               11-15 years
# 2549          3                      Low  ...               11-15 years
#
#      practitioner_active     Yr-Qtr appointment_date  consultation_fee  \
# 0                   TRUE  2020 Qtr2        6/20/2020           Unknown
# 1                   TRUE  2020 Qtr2        6/18/2020           Unknown
# 2                   TRUE  2020 Qtr2        5/15/2020           Unknown
# 3                   TRUE  2020 Qtr2        5/16/2020               500
# 4                   TRUE  2020 Qtr2        5/27/2020           Unknown
# ...                  ...        ...              ...               ...
# 2544                TRUE  2020 Qtr3         7/5/2020              1000
# 2546                TRUE  2020 Qtr2        5/23/2020               600
# 2547                TRUE  2020 Qtr2        6/23/2020               500
# 2548                TRUE  2020 Qtr2        5/25/2020           Unknown
# 2549                TRUE  2020 Qtr2        5/20/2020           Unknown
#
#      mins_appointment_duration   Duration_final  payment_method  \
# 0                           60  46 mins to 1 hr  online_credits
# 1                           30       15-30 mins  online_credits
# 2                           30       15-30 mins            free
# 3                           30       15-30 mins  online_credits
# 4                           15       15-30 mins            free
# ...                        ...              ...             ...
# 2544                        40       31-45 mins            free
# 2546                        30       15-30 mins            cash
# 2547                        36       31-45 mins            free
# 2548                        15       15-30 mins            cash
# 2549                        15       15-30 mins            free
#
#                                                  reason is_online
# 0                      35 weeks and 2 days consultation      True
# 1                        Aschemic heart disease; HASCVD      True
# 2                                                  ayan      True
# 3     Beside the lower part of my ear, there is a du...      True
# 4                                        blood in stool      True
# ...                                                 ...       ...
# 2544                                               test      True
# 2546                 Type 2 Diabetes Melitus Monitoring      True
# 2547         wavy vision followed by one sided headache      True
# 2548  Yellowish feet; Ffup on burnt fingers; Itchy ears      True
# 2549  Yung anak ko po may ubo 2weeks na. Madalang na...      True
#
# [2489 rows x 32 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(20, 12))  # Adjust the width and height as needed

# Get the total number of appointments
total_appointments = len(data['appointment_ID'])

# Calculate counts by 'specialty_type' and 'q8_rating_classification'
count_by_categories = data.groupby(['specialty_type', 'q8_rating_classification']).size().reset_index(name='count')

# Calculate percentages
count_by_categories['percentage'] = (count_by_categories['count'] / total_appointments) * 100

# Plotting
sns.catplot(data=count_by_categories, x='specialty_type', hue='q8_rating_classification', y='percentage', kind='bar')
plt.xticks(rotation=90)
plt.xlabel('Specialization Segment')
plt.ylabel('Percentage of Appointments')
plt.show()
# Out:
# B:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(12, 8))  # Adjust the width and height as needed

# Get the total number of appointments
total_appointments = len(data['appointment_ID'])

# Calculate counts by 'specialty_type' and 'q8_rating_classification'
count_by_categories = data.groupby(['specialty_type', 'q8_rating_classification']).size().reset_index(name='count')

# Calculate percentages
count_by_categories['percentage'] = (count_by_categories['count'] / total_appointments) * 100

# Plotting a scatter plot
plt.figure(figsize=(12, 8))  # Adjust the width and height as needed
sns.scatterplot(data=count_by_categories, x='specialty_type', y='q8_rating_classification', size='percentage', hue='q8_rating_classification')
plt.xticks(rotation=90)
plt.xlabel('Specialization Segment')
plt.ylabel('Ratings')
plt.legend(title='Rating Classification')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(12, 8))  # Adjust the width and height as needed

# Get the total number of appointments
total_appointments = len(data['appointment_ID'])

# Calculate counts by 'specialty_type' and 'q8_rating_classification'
count_by_categories = data.groupby(['specialty_type', 'q8_rating_classification']).size().reset_index(name='count')

# Plotting a scatter plot
plt.figure(figsize=(12, 8))  # Adjust the width and height as needed
sns.scatterplot(data=count_by_categories, x='specialty_type', y='q8_rating_classification', size='count', hue='q8_rating_classification')
plt.xticks(rotation=90)
plt.xlabel('Specialization Segment')
plt.ylabel('Ratings')
plt.legend(title='Rating Classification')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filter data for specific specialty types
selected_specialty_types = ['Surgical', 'Non surgical', 'Supporting']
filtered_data = data[data['specialty_type'].isin(selected_specialty_types)]

# Group data by 'specialty_type' and count the appointments
appointment_counts = filtered_data['specialty_type'].value_counts()

# Calculate percentages
total_appointments = appointment_counts.sum()
appointment_percentages = (appointment_counts / total_appointments) * 100

# Create a donut chart
plt.figure(figsize=(8, 8))
plt.pie(appointment_percentages, labels=appointment_percentages.index, autopct='%1.1f%%', startangle=90)
centre_circle = plt.Circle((0, 0), 0.7, color='black', fc='white', linewidth=1.25)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Provided data
data = [
    [5.5442315532001629, 1.4244186046511635, 1.261627906976744, 1.226744186046512, 1.2616279069767453, 1.1279069767441867],
    [12.922951487973911, 4.9505813953488378, 4.9040697674418618, 4.7325581395348841, 4.6017441860465125, 4.9418604651162781],
    [1.9567876070118222, 4.9387755102040805, 4.8979591836734686, 4.6530612244897966, 4.5102040816326507, 4.9183673469387763],
    [0.20383204239706482, 1.4, 1.6, 1.4, 1.8, 1.4],
    [4.6473705666530778, 1.5454545454545454, 1.411764705882353, 1.3957219251336908, 1.4064171122994653, 1.1764705882352948],
    [23.318385650224215, 4.8669833729216165, 4.8384798099762518, 4.6959619952494, 4.44061757719715, 4.9287410926365842]
]

# Define column names for ratings
columns = ['Rating1', 'Rating2', 'Rating3', 'Rating4', 'Rating5']

# Create DataFrame
df = pd.DataFrame(data, columns=columns)

# Create the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df, annot=True, cmap='YlGnBu', fmt=".2f", linewidths=0.5)
plt.title('Heatmap of Ratings')
plt.xlabel('Ratings')
plt.ylabel('Rows')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File B:\Anaconda\Lib\site-packages\pandas\core\internals\construction.py:934, in _finalize_columns_and_data(content, columns, dtype)
#     933 try:
# --> 934     columns = _validate_or_indexify_columns(contents, columns)
#     935 except AssertionError as err:
#     936     # GH#26429 do not raise user-facing AssertionError
#
# File B:\Anaconda\Lib\site-packages\pandas\core\internals\construction.py:981, in _validate_or_indexify_columns(content, columns)
#     979 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#     980     # caller's responsibility to check for this...
# --> 981     raise AssertionError(
#     982         f"{len(columns)} columns passed, passed data had "
#     983         f"{len(content)} columns"
#     984     )
#     985 if is_mi_list:
#     986     # check if nested list column, length of each sub-list should be equal
#
# AssertionError: 5 columns passed, passed data had 6 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 19
#      16 columns = ['Rating1', 'Rating2', 'Rating3', 'Rating4', 'Rating5']
#      18 # Create DataFrame
# ---> 19 df = pd.DataFrame(data, columns=columns)
#      21 # Create the heatmap
#      22 plt.figure(figsize=(10, 6))
#
# File B:\Anaconda\Lib\site-packages\pandas\core\frame.py:782, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     780     if columns is not None:
#     781         columns = ensure_index(columns)
# --> 782     arrays, columns, index = nested_data_to_arrays(
#     783         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     784         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#     785         data,
#     786         columns,
#     787         index,  # type: ignore[arg-type]
#     788         dtype,
#     789     )
#     790     mgr = arrays_to_mgr(
#     791         arrays,
#     792         columns,
#    (...)
#     795         typ=manager,
#     796     )
#     797 else:
#
# File B:\Anaconda\Lib\site-packages\pandas\core\internals\construction.py:498, in nested_data_to_arrays(data, columns, index, dtype)
#     495 if is_named_tuple(data[0]) and columns is None:
#     496     columns = ensure_index(data[0]._fields)
# --> 498 arrays, columns = to_arrays(data, columns, dtype=dtype)
#     499 columns = ensure_index(columns)
#     501 if index is None:
#
# File B:\Anaconda\Lib\site-packages\pandas\core\internals\construction.py:840, in to_arrays(data, columns, dtype)
#     837     data = [tuple(x) for x in data]
#     838     arr = _list_to_arrays(data)
# --> 840 content, columns = _finalize_columns_and_data(arr, columns, dtype)
#     841 return content, columns
#
# File B:\Anaconda\Lib\site-packages\pandas\core\internals\construction.py:937, in _finalize_columns_and_data(content, columns, dtype)
#     934     columns = _validate_or_indexify_columns(contents, columns)
#     935 except AssertionError as err:
#     936     # GH#26429 do not raise user-facing AssertionError
# --> 937     raise ValueError(err) from err
#     939 if len(contents) and contents[0].dtype == np.object_:
#     940     contents = convert_object_array(contents, dtype=dtype)
#
# ValueError: 5 columns passed, passed data had 6 columns
