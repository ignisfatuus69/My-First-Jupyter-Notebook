# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Preparation and Basic Information

# %% [markdown]
# ### Show columns and data types

# %%
#Showing all columns
appointments_data = pd.read_csv("appointments.csv")
appointments_data.info()
ratings_data = pd.read_csv("ratings.csv")
appointments_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23576 entries, 0 to 23575
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         23576 non-null  object
#  1   clinic_id                  23576 non-null  object
#  2   practice_id                20550 non-null  object
#  3   date                       23576 non-null  object
#  4   start_time                 23576 non-null  object
#  5   end_time                   23576 non-null  object
#  6   comments                   23576 non-null  object
#  7   approve                    23576 non-null  bool
#  8   payment_method             23576 non-null  object
#  9   reason                     812 non-null    object
#  10  inserted_at                23576 non-null  object
#  11  updated_at                 23576 non-null  object
#  12  status                     23546 non-null  object
# ...

# %% [markdown]
# ### Show an overview of the data with head

# %%
appointments_data.head(10)
# Out:
#                                      id                             clinic_id  \
# 0  82f350e7-55fb-4a03-b08f-d39b3b88f50a  7ed0e95e-20b2-4ea3-9ae8-a68974cc763b
# 1  e579625a-0511-4342-ae41-fe43548b5c31  8276f97d-4666-45a5-810f-bbc28dc61f4d
# 2  05e17346-9256-4a13-a4c6-7c42e1f4d696  a7be5475-07c2-40f5-a9ea-21e5756b2f0d
# 3  71278899-54d0-45b4-9d1c-bf79bf462089  914d3e83-08fd-4432-a874-e4e282cd0bbc
# 4  7745be1c-9e92-49c5-8b5e-5f6ffc796089  8dd44f49-e014-4e31-ab50-ee6169d26f81
# 5  9424aec3-7485-49de-8f71-0561247348d0  116cd8e4-a735-4460-823b-b7e4ba8b4177
# 6  239fdef0-0180-4415-8fa5-85c1a9ef8504  8276f97d-4666-45a5-810f-bbc28dc61f4d
# 7  459394f6-cda0-4e8c-bb74-eb5347fa6ba8  7ed0e95e-20b2-4ea3-9ae8-a68974cc763b
# 8  30a4e3c2-6dae-400b-833b-ac1724b65806  7ed0e95e-20b2-4ea3-9ae8-a68974cc763b
# 9  404f116f-e717-4088-a224-f92317d1fed0  7ed0e95e-20b2-4ea3-9ae8-a68974cc763b
#
#                             practice_id        date           start_time  \
# ...

# %%
ratings_data.head(10)
# Out:
#                                      id                       practitioner_id  \
# 0  2be8bf9b-0093-400e-b85c-4c40189349fb  04d61929-f7fb-496c-a0ed-68937256a68d
# 1  171ea637-313e-42f9-96ab-475c2b4f214a  04d61929-f7fb-496c-a0ed-68937256a68d
# 2  b1f4c313-b168-4e2a-b874-a791874e2f82                                   NaN
# 3  49d775c2-5564-4d54-95ef-830d8fd87b75  0953a70d-d20e-400e-8d40-d36642bdb5ab
# 4  bb80e507-2cc8-410d-a40d-b4d9da29f195  cabd6ab7-7148-40cc-b651-6af856235f38
# 5  e7de05a0-6651-4442-acb1-0dcb0d43fddf  b340572c-c189-4690-b1ef-93df8803c5eb
# 6  367a87a5-c3a1-41f2-a352-b73b61ba7d60  b340572c-c189-4690-b1ef-93df8803c5eb
# 7  0a5e7ddc-a2b7-4bf0-b6d9-02054c97f615  b340572c-c189-4690-b1ef-93df8803c5eb
# 8  485b602f-5194-4fd4-b650-0b7b1814affc  b287dbd3-734c-472a-a8f2-52e0b85d4be5
# 9  a2bb497d-ab08-4520-a8a9-8dd122c90060  b340572c-c189-4690-b1ef-93df8803c5eb
#
#                              patient_id                        appointment_id  \
# ...

# %% [markdown]
# ### Filtering columns that we need

# %% [markdown]
# #### Use case questions
#
# How do the ratings per practioner vary based on their specialization.
# Follow up question: What factors affect the ratings?
#
# What role does appointment duration play in patient satisfaction ratings that doctors receive?
#
# How does these factors vary across different medical specialties?
#
# What specific aspect can contribute to positive or negative ratings from patients,
